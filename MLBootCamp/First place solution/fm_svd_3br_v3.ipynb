# %%
data_dir = './data/mlboot_dataset/'
model_name = 'fm_svd_3br_v3'
results_dir = './results/'

import pandas as pd
import numpy as np
from sklearn.model_selection import KFold
from sklearn.metrics import roc_auc_score
import scipy.sparse as sp

# %%
df = pd.read_csv(data_dir + 'preprocessed_new.csv') 
q = pd.read_csv(data_dir + 'sessions.csv')
df = df.merge(q, on='uid', how='left')
del q
y = pd.read_table(data_dir + 'mlboot_train_answers.tsv')
y.columns = ['uid','target']
df = df.merge(y, on='uid', how='left')

df_train_index = df[~df.target.isnull()].index
df_test_index = df[df.target.isnull()].index

mat1 = sp.load_npz(data_dir+'dmat1.npz').tolil()
mat2 = sp.load_npz(data_dir+'dmat2.npz').tolil()
mat3 = sp.load_npz(data_dir+'dmat3.npz').tolil()
print(mat1.shape, mat2.shape, mat3.shape)

df['max_f1'] = mat1.tocsr().max(axis=1).todense()
df['max_f2'] = mat2.tocsr().max(axis=1).todense()
df['max_f3'] = mat3.tocsr().max(axis=1).todense()

print(mat1.shape, mat2.shape, mat3.shape)
# Out:
# (609018, 2053602) (609018, 20275) (609018, 1057788)
# (609018, 2053602) (609018, 20275) (609018, 1057788)

# %%
from sklearn.decomposition import TruncatedSVD
print('pca on matrix 1')
pca = TruncatedSVD(n_components = 500, algorithm='arpack')
mat1 = pca.fit_transform(mat1.astype(np.float32))
print('pca on matrix 2')
pca = TruncatedSVD(n_components = 500, algorithm='arpack')
mat2 = pca.fit_transform(mat2.astype(np.float32))
print('pca on matrix 3')
pca = TruncatedSVD(n_components = 500, algorithm='arpack')
mat3 = pca.fit_transform(mat3.astype(np.float32))
# Out:
# pca on matrix 1
# pca on matrix 2
# pca on matrix 3

# %%
from sklearn.preprocessing import StandardScaler 

X = df.loc[~df.target.isnull(),:].reset_index(drop=True)
x_te = df.loc[df.target.isnull(),:].reset_index(drop=True)

# %%
mat_pca1 = np.load(data_dir + 'pca_cat100.npy')
mat_pca2 = np.load(data_dir + 'svd_tfidf300.npy')
mat_pca = np.hstack([mat_pca1,mat_pca2])

# %%
from sklearn.preprocessing import MinMaxScaler
scaler_mat = MinMaxScaler(feature_range=(-1,1))
mat_pca = scaler_mat.fit_transform(mat_pca)
train_mat_pcat = mat_pca[df_train_index.tolist()]
test_mat_pcat = mat_pca[df_test_index.tolist()]

# %%
# %%time
from sklearn.preprocessing import MinMaxScaler
scaler_mat = MinMaxScaler(feature_range=(-1,1))
mat1 = scaler_mat.fit_transform(mat1)
scaler_mat = MinMaxScaler(feature_range=(-1,1))
mat2 = scaler_mat.fit_transform(mat2)
scaler_mat = MinMaxScaler(feature_range=(-1,1))
mat3 = scaler_mat.fit_transform(mat3)

train_mat1 = mat1[df_train_index.tolist()]
test_mat1 = mat1[df_test_index.tolist()]
train_mat2 = mat2[df_train_index.tolist()]
test_mat2 = mat2[df_test_index.tolist()]
train_mat3 = mat3[df_train_index.tolist()]
test_mat3 = mat3[df_test_index.tolist()]
import gc
#del mat1,mat2,mat3
#gc.collect()
print(np.min(train_mat1), np.max(train_mat1), np.std(train_mat1))
# Out:
# -1.0 1.0 0.233547
# CPU times: user 11.8 s, sys: 384 ms, total: 12.2 s
# Wall time: 4.73 s

# %%
import multiprocessing
cpu_cores = multiprocessing.cpu_count()

import tensorflow as tf
import keras
from keras.layers import *
from keras.models import *
from keras.callbacks import *
from keras import regularizers
from keras import optimizers
from keras import backend as K
from keras.utils import Sequence
cfg = K.tf.ConfigProto()
cfg.gpu_options.allow_growth = True
K.set_session(K.tf.Session(config=cfg))
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Data preprocessing

# %%
train_cols = ['num_times_cat_eq_0', 'num_times_cat_eq_1', 'num_times_cat_eq_2',
       'num_times_cat_eq_3', 'num_times_cat_eq_4', 'num_times_cat_eq_5',
       'records', 'max_days', 'min_days', 'sum_values_f1_max',
       'num_keys_f1_max', 'sum_values_f2_max', 'num_keys_f2_max',
       'sum_values_f3_max', 'num_keys_f3_max', 'sum_values_f1_mean',
       'num_keys_f1_mean', 'sum_values_f2_mean', 'num_keys_f2_mean',
       'sum_values_f3_mean', 'num_keys_f3_mean', 'max_day_cntr',
       'mean_day_cntr', 'diff_num_cats', 'unique_days',
        'sess_keys_mean', 'sess_keys_max', 'diff_key1_mean',
       'diff_key1_max', 'diff_key2_mean', 'diff_key2_max', 'diff_key3_mean',
       'diff_key3_max', 'quot_key1_mean', 'quot_key1_max', 'quot_key2_mean',
       'quot_key2_max', 'quot_key3_mean', 'quot_key3_max'
    ]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(-1,1))
scaler.fit(X[train_cols].fillna(0).values)
X[train_cols] = scaler.transform(X[train_cols].fillna(0).values)
x_te[train_cols] = scaler.transform(x_te[train_cols].fillna(0).values)

# %%
import math
from sklearn.metrics import log_loss
class CyclicLR(Callback):
    """This callback implements a cyclical learning rate policy (CLR).
    The method cycles the learning rate between two boundaries with
    some constant frequency, as detailed in this paper (https://arxiv.org/abs/1506.01186).
    The amplitude of the cycle can be scaled on a per-iteration or 
    per-cycle basis.
    This class has three built-in policies, as put forth in the paper.
    "triangular":
        A basic triangular cycle w/ no amplitude scaling.
    "triangular2":
        A basic triangular cycle that scales initial amplitude by half each cycle.
    "exp_range":
        A cycle that scales initial amplitude by gamma**(cycle iterations) at each 
        cycle iteration.
    For more detail, please see paper.
    
    # Example
        ```python
            clr = CyclicLR(base_lr=0.001, max_lr=0.006,
                                step_size=2000., mode='triangular')
            model.fit(X_train, Y_train, callbacks=[clr])
        ```
    
    Class also supports custom scaling functions:
        ```python
            clr_fn = lambda x: 0.5*(1+np.sin(x*np.pi/2.))
            clr = CyclicLR(base_lr=0.001, max_lr=0.006,
                                step_size=2000., scale_fn=clr_fn,
                                scale_mode='cycle')
            model.fit(X_train, Y_train, callbacks=[clr])
        ```    
    # Arguments
        base_lr: initial learning rate which is the
            lower boundary in the cycle.
        max_lr: upper boundary in the cycle. Functionally,
            it defines the cycle amplitude (max_lr - base_lr).
            The lr at any cycle is the sum of base_lr
            and some scaling of the amplitude; therefore 
            max_lr may not actually be reached depending on
            scaling function.
        step_size: number of training iterations per
            half cycle. Authors suggest setting step_size
            2-8 x training iterations in epoch.
        mode: one of {triangular, triangular2, exp_range}.
            Default 'triangular'.
            Values correspond to policies detailed above.
            If scale_fn is not None, this argument is ignored.
        gamma: constant in 'exp_range' scaling function:
            gamma**(cycle iterations)
        scale_fn: Custom scaling policy defined by a single
            argument lambda function, where 
            0 <= scale_fn(x) <= 1 for all x >= 0.
            mode paramater is ignored 
        scale_mode: {'cycle', 'iterations'}.
            Defines whether scale_fn is evaluated on 
            cycle number or cycle iterations (training
            iterations since start of cycle). Default is 'cycle'.
    """

    def __init__(self, base_lr=0.001, max_lr=0.006, step_size=2000., mode='triangular',
                 gamma=1., scale_fn=None, scale_mode='cycle'):
        super(CyclicLR, self).__init__()

        self.base_lr = base_lr
        self.max_lr = max_lr
        self.step_size = step_size
        self.mode = mode
        self.gamma = gamma
        if scale_fn == None:
            if self.mode == 'triangular':
                self.scale_fn = lambda x: 1.
                self.scale_mode = 'cycle'
            elif self.mode == 'triangular2':
                self.scale_fn = lambda x: 1/(2.**(x-1))
                self.scale_mode = 'cycle'
            elif self.mode == 'exp_range':
                self.scale_fn = lambda x: gamma**(x)
                self.scale_mode = 'iterations'
        else:
            self.scale_fn = scale_fn
            self.scale_mode = scale_mode
        self.clr_iterations = 0.
        self.trn_iterations = 0.
        self.history = {}

        self._reset()

    def _reset(self, new_base_lr=None, new_max_lr=None,
               new_step_size=None):
        """Resets cycle iterations.
        Optional boundary/step size adjustment.
        """
        if new_base_lr != None:
            self.base_lr = new_base_lr
        if new_max_lr != None:
            self.max_lr = new_max_lr
        if new_step_size != None:
            self.step_size = new_step_size
        self.clr_iterations = 0.
        
    def clr(self):
        cycle = np.floor(1+self.clr_iterations/(2*self.step_size))
        x = np.abs(self.clr_iterations/self.step_size - 2*cycle + 1)
        if self.scale_mode == 'cycle':
            return self.base_lr + (self.max_lr-self.base_lr)*np.maximum(0, (1-x))*self.scale_fn(cycle)
        else:
            return self.base_lr + (self.max_lr-self.base_lr)*np.maximum(0, (1-x))*self.scale_fn(self.clr_iterations)
        
    def on_train_begin(self, logs={}):
        logs = logs or {}

        if self.clr_iterations == 0:
            K.set_value(self.model.optimizer.lr, self.base_lr)
        else:
            K.set_value(self.model.optimizer.lr, self.clr())        
            
    def on_batch_end(self, epoch, logs=None):
        
        logs = logs or {}
        self.trn_iterations += 1
        self.clr_iterations += 1
        K.set_value(self.model.optimizer.lr, self.clr())

        self.history.setdefault('lr', []).append(K.get_value(self.model.optimizer.lr))
        self.history.setdefault('iterations', []).append(self.trn_iterations)

        for k, v in logs.items():
            self.history.setdefault(k, []).append(v)

            
class RocAucEvaluation(Callback):
    def __init__(self, X_seq, y, name, interval=1):
        super(Callback, self).__init__()
        self.X_seq, self.y = X_seq, y
        self.name = name
        self.interval = interval

    def on_epoch_end(self, epoch, logs={}):
        if epoch % self.interval == 0:
            y_pred = self.model.predict_generator(self.X_seq, steps=len(self.X_seq), 
                                                          use_multiprocessing=False, workers=1, 
                                                          max_queue_size=4*cpu_cores).ravel()
            auc = roc_auc_score(self.y, y_pred)
            logloss = log_loss(self.y, y_pred)
            logs[self.name+"_auc"] = auc
            logs[self.name+"_logloss"] = logloss
            print((self.name+"_auc: {:.8f}; "+"_logloss: {:.8f}; ").format(auc,logloss))
            
class FeatureSequence(Sequence):
    
    def __init__(self, X, y, inx, batch_size, shuffle=False):
        
        self.X, self.y = X, y
        self.batch_size = batch_size
        
        self.inx = inx
        self.shuffle = shuffle
        if self.shuffle:
            np.random.shuffle(self.inx)

    def __len__(self):
        return math.ceil(self.inx.shape[0] / self.batch_size)

    def __getitem__(self, i):
        batch_inx = self.inx[i*self.batch_size:(i+1)*self.batch_size]
        
        batch = [x[batch_inx] for x in self.X]
        #batch = [x[batch_inx].todense() for x in self.X]
        return batch, self.y[batch_inx]
    
    def on_epoch_end(self):
        if self.shuffle:
            np.random.shuffle(self.inx)

# %%
def split_inputs(X):
    return np.split(X, X.shape[-1], axis=-1)

def buildBaseModel():   
    num_inp = Input((len(train_cols),), name='num_inp')
    num_x = BatchNormalization()(num_inp)
    num_x = Dense(64, activation="relu")(num_x)
    num_x = BatchNormalization()(num_x)
    num_x = Dropout(0.4)(num_x)
    
    dense_inp = Input((train_mat_pcat.shape[1],), name='dense_inp')
    dense_x = BatchNormalization()(dense_inp)
    dense_x = Dense(128, activation="relu")(dense_x)
    dense_x = BatchNormalization()(dense_x)
    dense_x = Dense(64, activation="relu")(dense_x)
    dense_x = BatchNormalization()(dense_x)    
    dense_x = Dropout(0.5)(dense_x)    
    
    sparse_inp1 = Input((train_mat1.shape[1],), name='sparse_inp1')
    sparse1_x = BatchNormalization()(sparse_inp1)
    sparse1_x = Dense(128, activation="relu")(sparse1_x)
    sparse1_x = BatchNormalization()(sparse1_x)
    sparse1_x = Dense(64, activation="relu")(sparse1_x)
    sparse1_x = BatchNormalization()(sparse1_x)
    sparse1_x = Dropout(0.5)(sparse1_x)
    
    sparse_inp2 = Input((train_mat2.shape[1],), name='sparse_inp2')
    sparse2_x = BatchNormalization()(sparse_inp2)
    sparse2_x = Dense(128, activation="relu")(sparse2_x)
    sparse2_x = BatchNormalization()(sparse2_x)
    sparse2_x = Dense(64, activation="relu")(sparse2_x)
    sparse2_x = BatchNormalization()(sparse2_x)
    sparse2_x = Dropout(0.5)(sparse2_x)
    
    sparse_inp3 = Input((train_mat3.shape[1],), name='sparse_inp3')
    sparse3_x = BatchNormalization()(sparse_inp3)
    sparse3_x = Dense(128, activation="relu")(sparse3_x)
    sparse3_x = BatchNormalization()(sparse3_x)
    sparse3_x = Dense(64, activation="relu")(sparse3_x)
    sparse3_x = BatchNormalization()(sparse3_x)
    sparse3_x = Dropout(0.5)(sparse3_x)    
    
    x = concatenate([num_x, dense_x, sparse1_x, sparse3_x, sparse2_x, 
                     multiply([sparse1_x, sparse2_x]),
                     multiply([sparse1_x, sparse3_x]),
                     multiply([sparse2_x, sparse3_x]),
                     multiply([sparse1_x, sparse2_x, sparse3_x]),
                              ])
    
    x1 = Dense(1024, activation="relu")(x)
    x1 = BatchNormalization()(x1)
    x1 = Dropout(0.5)(x1)
    
    x2 = concatenate([x, x1])
    x2 = Dense(512, activation="relu")(x2)
    x2 = BatchNormalization()(x2)
    x2 = Dropout(0.5)(x2)
    
    x3 = concatenate([x, x1, x2])
    x3 = Dense(256, activation="relu")(x3)
    x3 = BatchNormalization()(x3)
    x3 = Dropout(0.5)(x3)
    
    x4 = x3
    x4 = Dense(128, activation="relu")(x4)
    x4 = BatchNormalization()(x4)
    x4 = Dropout(0.1)(x4)
    
    x_output = Dense(1, activation="sigmoid", name="output")(x4)
    return Model(inputs = [num_inp, dense_inp, sparse_inp1, sparse_inp2, sparse_inp3], outputs=x_output)

model = buildBaseModel()
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# sparse_inp1 (InputLayer)        (None, 500)          0
# __________________________________________________________________________________________________
# sparse_inp3 (InputLayer)        (None, 500)          0
# __________________________________________________________________________________________________
# sparse_inp2 (InputLayer)        (None, 500)          0
# __________________________________________________________________________________________________
# dense_inp (InputLayer)          (None, 400)          0
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 500)          2000        sparse_inp1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 500)          2000        sparse_inp3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 500)          2000        sparse_inp2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 400)          1600        dense_inp[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 128)          64128       batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 128)          64128       batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 128)          64128       batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# num_inp (InputLayer)            (None, 39)           0
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 128)          51328       batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 128)          512         dense_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 128)          512         dense_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 128)          512         dense_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 39)           156         num_inp[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 128)          512         dense_2[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 64)           8256        batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 64)           8256        batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 64)           8256        batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 64)           2560        batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 64)           8256        batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 64)           256         dense_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 64)           256         dense_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 64)           256         dense_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 64)           256         dense_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 64)           256         dense_3[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 64)           0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 64)           0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 64)           0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 64)           0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 64)           0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 64)           0           dropout_3[0][0]
#                                                                  dropout_4[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 64)           0           dropout_3[0][0]
#                                                                  dropout_5[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 64)           0           dropout_4[0][0]
#                                                                  dropout_5[0][0]
# __________________________________________________________________________________________________
# multiply_4 (Multiply)           (None, 64)           0           dropout_3[0][0]
#                                                                  dropout_4[0][0]
#                                                                  dropout_5[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 576)          0           dropout_1[0][0]
#                                                                  dropout_2[0][0]
#                                                                  dropout_3[0][0]
#                                                                  dropout_5[0][0]
#                                                                  dropout_4[0][0]
#                                                                  multiply_1[0][0]
#                                                                  multiply_2[0][0]
#                                                                  multiply_3[0][0]
#                                                                  multiply_4[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 1024)         590848      concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 1024)         4096        dense_10[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 1024)         0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 1600)         0           concatenate_1[0][0]
#                                                                  dropout_6[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 512)          819712      concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 512)          2048        dense_11[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 512)          0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 2112)         0           concatenate_1[0][0]
#                                                                  dropout_6[0][0]
#                                                                  dropout_7[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 256)          540928      concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 256)          1024        dense_12[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 256)          0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 128)          32896       dropout_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 128)          512         dense_13[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 128)          0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            129         dropout_9[0][0]
# ==================================================================================================
# Total params: 2,282,573
# Trainable params: 2,273,191
# Non-trainable params: 9,382
# __________________________________________________________________________________________________

# %%
from sklearn.feature_selection import SelectPercentile
from sklearn.preprocessing import MaxAbsScaler 
from sklearn.preprocessing import minmax_scale
from sklearn.model_selection import KFold
TRN_BATCH_SIZE = 512
INF_BATCH_SIZE = 512

n_folds = 10
kf = KFold(n_splits=n_folds, shuffle=True, random_state=39)
epochs = 100
pred = np.zeros(y.shape)
test_pred = 0
ifold = 0
cpu_cores = 4

fold_auc = []

y = X.target.values

for trn_inx, val_inx in kf.split(y):
    print("Training fold {}".format(ifold))
    K.clear_session()

    
    model_file_name = model_name+"__f"+str(ifold)
    model_file = results_dir+model_file_name+'.h5'   
      
    model = buildBaseModel()    
    
    trn_seq = FeatureSequence([X.loc[trn_inx,train_cols].values, 
                               train_mat_pcat[trn_inx],
                               train_mat1[trn_inx],
                               train_mat2[trn_inx],
                               train_mat3[trn_inx]
                              ], 
                              y[trn_inx], np.array(list(range(len(trn_inx)))), TRN_BATCH_SIZE, shuffle=True)
    val_seq = FeatureSequence([X.loc[val_inx,train_cols].values, 
                               train_mat_pcat[val_inx],
                               train_mat1[val_inx],
                               train_mat2[val_inx],
                               train_mat3[val_inx]
                              ], 
                              y[val_inx], np.array(list(range(len(val_inx)))), INF_BATCH_SIZE, shuffle=False)
    te_seq = FeatureSequence([x_te[train_cols].values, 
                               test_mat_pcat,
                               test_mat1,
                               test_mat2,
                               test_mat3
                             ], 
                              y, np.array(list(range(len(x_te)))), INF_BATCH_SIZE, shuffle=False)
    
    
    # Callbacks
    model_checkpoint = ModelCheckpoint(model_file, monitor='val_auc', verbose=1, mode='max',
                                       save_best_only=True, save_weights_only=False, period=1)
    clr = CyclicLR(base_lr=0.0001, max_lr=0.001, step_size=2*math.ceil(len(trn_seq)), mode='triangular2')
    early_stop = EarlyStopping(monitor='val_auc', min_delta=0, patience=4, verbose=1, mode='max')
    mse_eval = RocAucEvaluation(val_seq, y[val_inx], 'val')
    
    # Training
    opt=optimizers.Nadam()
    model.compile(optimizer=opt, loss='binary_crossentropy')

    model.fit_generator(
        generator=trn_seq, steps_per_epoch=len(trn_seq),
        initial_epoch=0, epochs=epochs, shuffle=False, verbose=2,
        callbacks=[mse_eval, model_checkpoint, early_stop, clr], #
        class_weight={0:0.06,1:0.94},
        use_multiprocessing=False, workers=1, max_queue_size=4*cpu_cores)
    
     
    # Predicting
    print("\nPredicting fold {}".format(ifold))
    del model  
    model = load_model(model_file, compile=True)
    pred[val_inx] = model.predict_generator(val_seq, steps=len(val_seq), 
                                                    use_multiprocessing=False, workers=1, 
                                                    max_queue_size=4*cpu_cores).ravel()
    
    auc = roc_auc_score(y[val_inx], pred[val_inx])
    logloss = log_loss(y[val_inx], pred[val_inx])
    fold_auc.append(auc)
    print("fold: {}, auc: {}".format(ifold, auc))
    print("fold: {}, logloss: {}".format(ifold, logloss))
    print()
    
    test_pred += minmax_scale(model.predict_generator(te_seq, steps=len(te_seq), 
                                                    use_multiprocessing=False, workers=1, 
                                                    max_queue_size=4*cpu_cores).ravel())/n_folds
    ifold += 1
    
    gc.collect()
# Out:
# Training fold 0
# Epoch 1/100
#  - 16s - loss: 0.0770
# val_auc: 0.63980354; _logloss: 0.60017974;
#
# Epoch 00001: val_auc improved from -inf to 0.63980, saving model to ./results/fm_svd_3br_v3__f0.h5
# Epoch 2/100
#  - 14s - loss: 0.0699
# val_auc: 0.66749822; _logloss: 0.57377404;
#
# Epoch 00002: val_auc improved from 0.63980 to 0.66750, saving model to ./results/fm_svd_3br_v3__f0.h5
# Epoch 3/100
#  - 14s - loss: 0.0671
# val_auc: 0.67082585; _logloss: 0.55454657;
#
# Epoch 00003: val_auc improved from 0.66750 to 0.67083, saving model to ./results/fm_svd_3br_v3__f0.h5
# Epoch 4/100
#  - 14s - loss: 0.0655
# val_auc: 0.67402920; _logloss: 0.55058761;
#
# Epoch 00004: val_auc improved from 0.67083 to 0.67403, saving model to ./results/fm_svd_3br_v3__f0.h5
# Epoch 5/100
#  - 14s - loss: 0.0647
# val_auc: 0.67207642; _logloss: 0.53501637;
#
# Epoch 00005: val_auc did not improve
# Epoch 6/100
#  - 14s - loss: 0.0644
# val_auc: 0.66945054; _logloss: inf;
#
# Epoch 00006: val_auc did not improve
# Epoch 7/100
#  - 14s - loss: 0.0633
# val_auc: 0.66470788; _logloss: 0.53012229;
#
# Epoch 00007: val_auc did not improve
# Epoch 8/100
#  - 14s - loss: 0.0611
# val_auc: 0.66121693; _logloss: 0.50705376;
#
# Epoch 00008: val_auc did not improve
# Epoch 00008: early stopping
#
# Predicting fold 0
# fold: 0, auc: 0.6740291987355469
# fold: 0, logloss: 0.5505876097729882
#
# Training fold 1
# Epoch 1/100
#  - 16s - loss: 0.0768
# /root/miniconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1694: RuntimeWarning: divide by zero encountered in log
#   loss = -(transformed_labels * np.log(y_pred)).sum(axis=1)
# /root/miniconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1694: RuntimeWarning: invalid value encountered in multiply
#   loss = -(transformed_labels * np.log(y_pred)).sum(axis=1)
# val_auc: 0.66125738; _logloss: nan;
#
# Epoch 00001: val_auc improved from -inf to 0.66126, saving model to ./results/fm_svd_3br_v3__f1.h5
# Epoch 2/100
#  - 14s - loss: 0.0696
# val_auc: 0.67626031; _logloss: 0.58842698;
#
# Epoch 00002: val_auc improved from 0.66126 to 0.67626, saving model to ./results/fm_svd_3br_v3__f1.h5
# Epoch 3/100
#  - 14s - loss: 0.0672
# val_auc: 0.68089313; _logloss: nan;
#
# Epoch 00003: val_auc improved from 0.67626 to 0.68089, saving model to ./results/fm_svd_3br_v3__f1.h5
# Epoch 4/100
#  - 14s - loss: 0.0656
# val_auc: 0.68283867; _logloss: inf;
#
# Epoch 00004: val_auc improved from 0.68089 to 0.68284, saving model to ./results/fm_svd_3br_v3__f1.h5
# Epoch 5/100
#  - 14s - loss: 0.0644
# val_auc: 0.68302686; _logloss: inf;
#
# Epoch 00005: val_auc improved from 0.68284 to 0.68303, saving model to ./results/fm_svd_3br_v3__f1.h5
# Epoch 6/100
#  - 14s - loss: 0.0642
# val_auc: 0.67898526; _logloss: 0.52976912;
#
# Epoch 00006: val_auc did not improve
# Epoch 7/100
#  - 14s - loss: 0.0632
# val_auc: 0.67576386; _logloss: 0.53361856;
#
# Epoch 00007: val_auc did not improve
# Epoch 8/100
#  - 14s - loss: 0.0608
# val_auc: 0.67086918; _logloss: 0.49339463;
#
# Epoch 00008: val_auc did not improve
# Epoch 9/100
#  - 14s - loss: 0.0590
# val_auc: 0.66474034; _logloss: 0.47487061;
#
# Epoch 00009: val_auc did not improve
# Epoch 00009: early stopping
#
# Predicting fold 1
# fold: 1, auc: 0.6830268640589994
# fold: 1, logloss: 0.5463415612676688
#
# Training fold 2
# Epoch 1/100
#  - 16s - loss: 0.0757
# val_auc: 0.65704844; _logloss: 0.58095937;
#
# Epoch 00001: val_auc improved from -inf to 0.65705, saving model to ./results/fm_svd_3br_v3__f2.h5
# Epoch 2/100
#  - 14s - loss: 0.0693
# val_auc: 0.67646194; _logloss: inf;
#
# Epoch 00002: val_auc improved from 0.65705 to 0.67646, saving model to ./results/fm_svd_3br_v3__f2.h5
# Epoch 3/100
#  - 14s - loss: 0.0670
# val_auc: 0.67857987; _logloss: inf;
#
# Epoch 00003: val_auc improved from 0.67646 to 0.67858, saving model to ./results/fm_svd_3br_v3__f2.h5
# Epoch 4/100
#  - 14s - loss: 0.0655
# val_auc: 0.67984014; _logloss: 0.54592845;
#
# Epoch 00004: val_auc improved from 0.67858 to 0.67984, saving model to ./results/fm_svd_3br_v3__f2.h5
# Epoch 5/100
#  - 14s - loss: 0.0644
# val_auc: 0.67835978; _logloss: 0.53784844;
#
# Epoch 00005: val_auc did not improve
# Epoch 6/100
#  - 14s - loss: 0.0640
# val_auc: 0.67654592; _logloss: 0.52487398;
#
# Epoch 00006: val_auc did not improve
# Epoch 7/100
#  - 14s - loss: 0.0632
# val_auc: 0.67192021; _logloss: 0.53063771;
#
# Epoch 00007: val_auc did not improve
# Epoch 8/100
#  - 14s - loss: 0.0607
# val_auc: 0.66722303; _logloss: inf;
#
# Epoch 00008: val_auc did not improve
# Epoch 00008: early stopping
#
# Predicting fold 2
# fold: 2, auc: 0.6798401413276919
# fold: 2, logloss: 0.5459284473146123
#
# Training fold 3
# Epoch 1/100
#  - 16s - loss: 0.0766
# val_auc: 0.63085986; _logloss: nan;
#
# Epoch 00001: val_auc improved from -inf to 0.63086, saving model to ./results/fm_svd_3br_v3__f3.h5
# Epoch 2/100
#  - 14s - loss: 0.0696
# val_auc: 0.66042716; _logloss: inf;
#
# Epoch 00002: val_auc improved from 0.63086 to 0.66043, saving model to ./results/fm_svd_3br_v3__f3.h5
# Epoch 3/100
#  - 14s - loss: 0.0668
# val_auc: 0.66226174; _logloss: inf;
#
# Epoch 00003: val_auc improved from 0.66043 to 0.66226, saving model to ./results/fm_svd_3br_v3__f3.h5
# Epoch 4/100
#  - 14s - loss: 0.0654
# val_auc: 0.66277039; _logloss: inf;
#
# Epoch 00004: val_auc improved from 0.66226 to 0.66277, saving model to ./results/fm_svd_3br_v3__f3.h5
# Epoch 5/100
#  - 14s - loss: 0.0643
# val_auc: 0.66133991; _logloss: 0.53333813;
#
# Epoch 00005: val_auc did not improve
# Epoch 6/100
#  - 14s - loss: 0.0641
# val_auc: 0.65750978; _logloss: inf;
#
# Epoch 00006: val_auc did not improve
# Epoch 7/100
#  - 14s - loss: 0.0632
# val_auc: 0.65554090; _logloss: inf;
#
# Epoch 00007: val_auc did not improve
# Epoch 8/100
#  - 14s - loss: 0.0608
# val_auc: 0.65120497; _logloss: inf;
#
# Epoch 00008: val_auc did not improve
# Epoch 00008: early stopping
#
# Predicting fold 3
# fold: 3, auc: 0.662770386142752
# fold: 3, logloss: 0.5398906983325972
#
# Training fold 4
# Epoch 1/100
#  - 16s - loss: 0.0766
# val_auc: 0.67320475; _logloss: 0.56715837;
#
# Epoch 00001: val_auc improved from -inf to 0.67320, saving model to ./results/fm_svd_3br_v3__f4.h5
# Epoch 2/100
#  - 14s - loss: 0.0695
# val_auc: 0.69361353; _logloss: inf;
#
# Epoch 00002: val_auc improved from 0.67320 to 0.69361, saving model to ./results/fm_svd_3br_v3__f4.h5
# Epoch 3/100
#  - 14s - loss: 0.0670
# val_auc: 0.69361611; _logloss: inf;
#
# Epoch 00003: val_auc improved from 0.69361 to 0.69362, saving model to ./results/fm_svd_3br_v3__f4.h5
# Epoch 4/100
#  - 14s - loss: 0.0655
# val_auc: 0.69476522; _logloss: 0.54787070;
#
# Epoch 00004: val_auc improved from 0.69362 to 0.69477, saving model to ./results/fm_svd_3br_v3__f4.h5
# Epoch 5/100
#  - 14s - loss: 0.0645
# val_auc: 0.69282616; _logloss: 0.53748293;
#
# Epoch 00005: val_auc did not improve
# Epoch 6/100
#  - 14s - loss: 0.0642
# val_auc: 0.69007857; _logloss: 0.54013297;
#
# Epoch 00006: val_auc did not improve
# Epoch 7/100
#  - 14s - loss: 0.0631
# val_auc: 0.68363717; _logloss: 0.52292660;
#
# Epoch 00007: val_auc did not improve
# Epoch 8/100
#  - 14s - loss: 0.0608
# val_auc: 0.67445083; _logloss: 0.50370219;
#
# Epoch 00008: val_auc did not improve
# Epoch 00008: early stopping
#
# Predicting fold 4
# fold: 4, auc: 0.6947652173274528
# fold: 4, logloss: 0.5478707011633918
#
# Training fold 5
# Epoch 1/100
#  - 16s - loss: 0.0766
# val_auc: 0.65123252; _logloss: inf;
#
# Epoch 00001: val_auc improved from -inf to 0.65123, saving model to ./results/fm_svd_3br_v3__f5.h5
# Epoch 2/100
#  - 14s - loss: 0.0697
# val_auc: 0.68022236; _logloss: inf;
#
# Epoch 00002: val_auc improved from 0.65123 to 0.68022, saving model to ./results/fm_svd_3br_v3__f5.h5
# Epoch 3/100
#  - 14s - loss: 0.0670
# val_auc: 0.68360396; _logloss: 0.55847830;
#
# Epoch 00003: val_auc improved from 0.68022 to 0.68360, saving model to ./results/fm_svd_3br_v3__f5.h5
# Epoch 4/100
#  - 14s - loss: 0.0655
# val_auc: 0.68351671; _logloss: 0.55451945;
#
# Epoch 00004: val_auc did not improve
# Epoch 5/100
#  - 14s - loss: 0.0646
# val_auc: 0.68140087; _logloss: 0.55134263;
#
# Epoch 00005: val_auc did not improve
# Epoch 6/100
#  - 14s - loss: 0.0642
# val_auc: 0.67842124; _logloss: 0.55796109;
#
# Epoch 00006: val_auc did not improve
# Epoch 7/100
#  - 14s - loss: 0.0632
# val_auc: 0.67563849; _logloss: 0.52736791;
#
# Epoch 00007: val_auc did not improve
# Epoch 00007: early stopping
#
# Predicting fold 5
# fold: 5, auc: 0.6836039557694754
# fold: 5, logloss: 0.5584782961328053
#
# Training fold 6
# Epoch 1/100
#  - 16s - loss: 0.0767
# val_auc: 0.64528514; _logloss: inf;
#
# Epoch 00001: val_auc improved from -inf to 0.64529, saving model to ./results/fm_svd_3br_v3__f6.h5
# Epoch 2/100
#  - 14s - loss: 0.0697
# val_auc: 0.67978876; _logloss: nan;
#
# Epoch 00002: val_auc improved from 0.64529 to 0.67979, saving model to ./results/fm_svd_3br_v3__f6.h5
# Epoch 3/100
#  - 14s - loss: 0.0672
# val_auc: 0.68362717; _logloss: 0.54312395;
#
# Epoch 00003: val_auc improved from 0.67979 to 0.68363, saving model to ./results/fm_svd_3br_v3__f6.h5
# Epoch 4/100
#  - 14s - loss: 0.0655
# val_auc: 0.68641224; _logloss: inf;
#
# Epoch 00004: val_auc improved from 0.68363 to 0.68641, saving model to ./results/fm_svd_3br_v3__f6.h5
# Epoch 5/100
#  - 14s - loss: 0.0646
# val_auc: 0.68455999; _logloss: 0.52730370;
#
# Epoch 00005: val_auc did not improve
# Epoch 6/100
#  - 14s - loss: 0.0644
# val_auc: 0.67974337; _logloss: 0.52557198;
#
# Epoch 00006: val_auc did not improve
# Epoch 7/100
#  - 14s - loss: 0.0634
# val_auc: 0.67706640; _logloss: 0.53677347;
#
# Epoch 00007: val_auc did not improve
# Epoch 8/100
#  - 14s - loss: 0.0610
# val_auc: 0.67245927; _logloss: 0.49386882;
#
# Epoch 00008: val_auc did not improve
# Epoch 00008: early stopping
#
# Predicting fold 6
# fold: 6, auc: 0.68641223804329
# fold: 6, logloss: 0.5308091078950102
#
# Training fold 7
# Epoch 1/100
#  - 16s - loss: 0.0763
# val_auc: 0.65730525; _logloss: nan;
#
# Epoch 00001: val_auc improved from -inf to 0.65731, saving model to ./results/fm_svd_3br_v3__f7.h5
# Epoch 2/100
#  - 14s - loss: 0.0696
# val_auc: 0.68906698; _logloss: inf;
#
# Epoch 00002: val_auc improved from 0.65731 to 0.68907, saving model to ./results/fm_svd_3br_v3__f7.h5
# Epoch 3/100
#  - 14s - loss: 0.0670
# val_auc: 0.68907061; _logloss: inf;
#
# Epoch 00003: val_auc improved from 0.68907 to 0.68907, saving model to ./results/fm_svd_3br_v3__f7.h5
# Epoch 4/100
#  - 14s - loss: 0.0654
# val_auc: 0.68884637; _logloss: inf;
#
# Epoch 00004: val_auc did not improve
# Epoch 5/100
#  - 14s - loss: 0.0643
# val_auc: 0.68781021; _logloss: inf;
#
# Epoch 00005: val_auc did not improve
# Epoch 6/100
#  - 14s - loss: 0.0643
# val_auc: 0.68138890; _logloss: inf;
#
# Epoch 00006: val_auc did not improve
# Epoch 7/100
#  - 14s - loss: 0.0632
# val_auc: 0.68094034; _logloss: inf;
#
# Epoch 00007: val_auc did not improve
# Epoch 00007: early stopping
#
# Predicting fold 7
# fold: 7, auc: 0.6890706082082569
# fold: 7, logloss: 0.5331268382659106
#
# Training fold 8
# Epoch 1/100
#  - 16s - loss: 0.0766
# val_auc: 0.65282386; _logloss: inf;
#
# Epoch 00001: val_auc improved from -inf to 0.65282, saving model to ./results/fm_svd_3br_v3__f8.h5
# Epoch 2/100
#  - 14s - loss: 0.0695
# val_auc: 0.68206910; _logloss: inf;
#
# Epoch 00002: val_auc improved from 0.65282 to 0.68207, saving model to ./results/fm_svd_3br_v3__f8.h5
# Epoch 3/100
#  - 14s - loss: 0.0671
# val_auc: 0.68768669; _logloss: inf;
#
# Epoch 00003: val_auc improved from 0.68207 to 0.68769, saving model to ./results/fm_svd_3br_v3__f8.h5
# Epoch 4/100
#  - 14s - loss: 0.0654
# val_auc: 0.68914885; _logloss: inf;
#
# Epoch 00004: val_auc improved from 0.68769 to 0.68915, saving model to ./results/fm_svd_3br_v3__f8.h5
# Epoch 5/100
#  - 14s - loss: 0.0644
# val_auc: 0.68600449; _logloss: inf;
#
# Epoch 00005: val_auc did not improve
# Epoch 6/100
#  - 14s - loss: 0.0640
# val_auc: 0.68324413; _logloss: 0.53012347;
#
# Epoch 00006: val_auc did not improve
# Epoch 7/100
#  - 14s - loss: 0.0631
# val_auc: 0.67511918; _logloss: 0.51184755;
#
# Epoch 00007: val_auc did not improve
# Epoch 8/100
#  - 14s - loss: 0.0608
# val_auc: 0.66899161; _logloss: 0.48895182;
#
# Epoch 00008: val_auc did not improve
# Epoch 00008: early stopping
#
# Predicting fold 8
# fold: 8, auc: 0.6891488533186474
# fold: 8, logloss: 0.53516082912048
#
# Training fold 9
# Epoch 1/100
#  - 16s - loss: 0.0757
# val_auc: 0.65743792; _logloss: inf;
#
# Epoch 00001: val_auc improved from -inf to 0.65744, saving model to ./results/fm_svd_3br_v3__f9.h5
# Epoch 2/100
#  - 14s - loss: 0.0698
# val_auc: 0.67944208; _logloss: inf;
#
# Epoch 00002: val_auc improved from 0.65744 to 0.67944, saving model to ./results/fm_svd_3br_v3__f9.h5
# Epoch 3/100
#  - 14s - loss: 0.0671
# val_auc: 0.68485818; _logloss: inf;
#
# Epoch 00003: val_auc improved from 0.67944 to 0.68486, saving model to ./results/fm_svd_3br_v3__f9.h5
# Epoch 4/100
#  - 14s - loss: 0.0655
# val_auc: 0.68621545; _logloss: 0.54676321;
#
# Epoch 00004: val_auc improved from 0.68486 to 0.68622, saving model to ./results/fm_svd_3br_v3__f9.h5
# Epoch 5/100
#  - 14s - loss: 0.0647
# val_auc: 0.68540828; _logloss: inf;
#
# Epoch 00005: val_auc did not improve
# Epoch 6/100
#  - 14s - loss: 0.0645
# val_auc: 0.68206026; _logloss: inf;
#
# Epoch 00006: val_auc did not improve
# Epoch 7/100
#  - 14s - loss: 0.0634
# val_auc: 0.67822308; _logloss: 0.52136367;
#
# Epoch 00007: val_auc did not improve
# Epoch 8/100
#  - 14s - loss: 0.0614
# val_auc: 0.67457478; _logloss: 0.49203969;
#
# Epoch 00008: val_auc did not improve
# Epoch 00008: early stopping
#
# Predicting fold 9
# fold: 9, auc: 0.6862154532101299
# fold: 9, logloss: 0.5467632065120264

# %%
print(fold_auc)
print(np.mean(fold_auc), np.std(fold_auc))
roc_auc_score(X.target.values, pred)
# Out:
# [0.6740291987355469, 0.68302686405899937, 0.67984014132769188, 0.66277038614275197, 0.69476521732745278, 0.68360395576947541, 0.68641223804328999, 0.68907060820825694, 0.68914885331864739, 0.68621545321012989]
# 0.682888291614 0.00857322275057
# 0.68159078371591741

# %%
np.save(results_dir + 'train_' + model_name +'.npy', pred)
sample_sub = pd.read_table(data_dir+'mlboot_test.tsv')

# %%
sub = x_te[['uid','target']].copy()
sub['target'] = test_pred
sub.columns = ['cuid','target']
sample_sub = sample_sub.merge(sub, on='cuid', how='left')
np.save(results_dir + 'test_' + model_name +'.npy', sample_sub.target.values)
print('isnull?',sample_sub.target.isnull().any())
sample_sub.head()
# Out:
# isnull? False
#                                cuid    target
# 0  888b238b4d14c03173baa375a739f6bc  0.567551
# 1  ac4b8244f3ae82df511b002257473c11  0.400986
# 2  483d8b91e49522c8a5bbe37f3872c749  0.442321
# 3  4c7ec46a0e88a7e1e1cedd2d526d5d61  0.421086
# 4  fdbfba9842ff0bf86d600eb334c7c42b  0.400907

# %%
sample_sub[['target']].to_csv(results_dir + model_name + '.csv', header=False, index=False)

# %%
val_seq = FeatureSequence([X.loc[val_inx,train_cols].values, 
                           train_mat_pcat[val_inx],
                           train_mat1[val_inx],
                           train_mat2[val_inx],
                           train_mat3[val_inx]
                          ], 
                          y[val_inx], np.array(list(range(len(val_inx)))), INF_BATCH_SIZE, shuffle=False)

# %%
model.predict_generator(val_seq, steps=len(val_seq), 
                                                use_multiprocessing=False, workers=1, 
                                                max_queue_size=4*cpu_cores).ravel()
# Out:
# array([ 0.45494437,  0.42481354,  0.45292914, ...,  0.39882585,
#         0.41881174,  0.41585764], dtype=float32)

# %%
print(fold_auc)
print(np.mean(fold_auc), np.std(fold_auc))
# Out:
# [0.67407794423432454, 0.65804794886639673, 0.65067841889905376, 0.66493955106895541, 0.66182499546367923, 0.66190969589725657, 0.65623060743527573, 0.6691731672095117, 0.65720702631251637, 0.66147049027858973]
# 0.661555984567 0.00635904933355

# %%
sample_sub.head()
# Out:
#                                cuid    target
# 0  888b238b4d14c03173baa375a739f6bc  0.058912
# 1  ac4b8244f3ae82df511b002257473c11  0.047257
# 2  483d8b91e49522c8a5bbe37f3872c749  0.059204
# 3  4c7ec46a0e88a7e1e1cedd2d526d5d61  0.042887
# 4  fdbfba9842ff0bf86d600eb334c7c42b  0.030320
