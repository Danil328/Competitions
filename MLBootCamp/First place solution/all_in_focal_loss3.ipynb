# %%
data_dir = './data/mlboot_dataset/'
results_dir = './results/'

import pandas as pd
import numpy as np
from sklearn.model_selection import KFold
from sklearn.metrics import roc_auc_score
import lightgbm as lgb
import scipy.sparse as sp

# %%
df = pd.read_csv(data_dir + 'preprocessed_new.csv') 
y = pd.read_table(data_dir + 'mlboot_train_answers.tsv')
y.columns = ['uid','target']
df = df.merge(y, on='uid', how='left')

mat1 = sp.load_npz(data_dir+'dmat1.npz').tolil()
mat2 = sp.load_npz(data_dir+'dmat2.npz').tolil()
mat3 = sp.load_npz(data_dir+'dmat3.npz').tolil()
print(mat1.shape, mat2.shape, mat3.shape)

df['max_f1'] = mat1.tocsr().max(axis=1).todense()
df['max_f2'] = mat2.tocsr().max(axis=1).todense()
df['max_f3'] = mat3.tocsr().max(axis=1).todense()

limit = 4
mat1 = mat1.tocsc()[:, np.where(mat1.getnnz(axis=0) > limit)[0]].tocsr()
mat2 = mat2.tocsc()[:, np.where(mat2.getnnz(axis=0) > limit)[0]].tocsr()
mat3 = mat3.tocsc()[:, np.where(mat3.getnnz(axis=0) > limit)[0]].tocsr()
print(mat1.shape, mat2.shape, mat3.shape)
# Out:
# (609018, 2053602) (609018, 2812610) (609018, 1057788)
# (609018, 598456) (609018, 20275) (609018, 92738)

# %%
df_train_index = df[~df.target.isnull()].index
df_test_index = df[df.target.isnull()].index

X = df.loc[~df.target.isnull(),:].reset_index(drop=True)
x_te = df.loc[df.target.isnull(),:].reset_index(drop=True)

# %%
from sklearn.decomposition import TruncatedSVD
print('pca on matrix 1')
pca = TruncatedSVD(n_components = 200, algorithm='arpack')
mat1_pca = pca.fit_transform(mat1.astype(np.float32))
print('pca on matrix 3')
pca = TruncatedSVD(n_components = 200, algorithm='arpack')
mat3_pca = pca.fit_transform(mat3.astype(np.float32))
# Out:
# pca on matrix 1
# pca on matrix 3

# %%
train_mat1 = mat1[df_train_index.tolist()]
test_mat1 = mat1[df_test_index.tolist()]
train_mat1_pca = mat1_pca[df_train_index.tolist()]
test_mat1_pca = mat1_pca[df_test_index.tolist()]
train_mat2 = mat2[df_train_index.tolist()]
test_mat2 = mat2[df_test_index.tolist()]
train_mat3 = mat3[df_train_index.tolist()]
test_mat3 = mat3[df_test_index.tolist()]
train_mat3_pca = mat3_pca[df_train_index.tolist()]
test_mat3_pca = mat3_pca[df_test_index.tolist()]
import gc
del mat1,mat2,mat3,mat1_pca,mat3_pca
gc.collect()
# Out:
# 35

# %%
from sklearn.preprocessing import normalize
train_mat1 = normalize(train_mat1, norm='l1', axis=1)
test_mat1 = normalize(test_mat1, norm='l1', axis=1)
train_mat2 = normalize(train_mat2, norm='l1', axis=1)
test_mat2 = normalize(test_mat2, norm='l1', axis=1)
train_mat3 = normalize(train_mat3, norm='l1', axis=1)
test_mat3 = normalize(test_mat3, norm='l1', axis=1)

# %%
y = X.target.values
from sklearn.feature_selection import SelectPercentile
sp = SelectPercentile(percentile=2)
sp.fit(train_mat1, y)
train_mat1 = sp.transform(train_mat1)
test_mat1 = sp.transform(test_mat1)
sp = SelectPercentile(percentile=2)
sp.fit(train_mat3, y)
train_mat3 = sp.transform(train_mat3)
test_mat3 = sp.transform(test_mat3)
# Out:
# /root/miniconda3/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:113: UserWarning: Features [0 0 0 ..., 0 0 0] are constant.
#   UserWarning)
# /root/miniconda3/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:114: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw

# %%
import multiprocessing
cpu_cores = multiprocessing.cpu_count()

import tensorflow as tf
import keras
from keras.layers import *
from keras.models import *
from keras.callbacks import *
from keras import regularizers
from keras import optimizers
from keras import backend as K
from keras.utils import Sequence
cfg = K.tf.ConfigProto()
cfg.gpu_options.allow_growth = True
K.set_session(K.tf.Session(config=cfg))

# %% [markdown]
# # Data preprocessing

# %%
df.columns
# Out:
# Index(['uid', 'num_times_cat_eq_0', 'num_times_cat_eq_1', 'num_times_cat_eq_2',
#        'num_times_cat_eq_3', 'num_times_cat_eq_4', 'num_times_cat_eq_5',
#        'records', 'max_days', 'min_days', 'sum_values_f1_max',
#        'num_keys_f1_max', 'sum_values_f2_max', 'num_keys_f2_max',
#        'sum_values_f3_max', 'num_keys_f3_max', 'sum_values_f1_mean',
#        'num_keys_f1_mean', 'sum_values_f2_mean', 'num_keys_f2_mean',
#        'sum_values_f3_mean', 'num_keys_f3_mean', 'max_day_cntr',
#        'mean_day_cntr', 'nuniq_keys_f1_cat0', 'nuniq_keys_f2_cat0',
#        'nuniq_keys_f3_cat0', 'nuniq_keys_f1_cat1', 'nuniq_keys_f2_cat1',
#        'nuniq_keys_f3_cat1', 'nuniq_keys_f1_cat2', 'nuniq_keys_f2_cat2',
#        'nuniq_keys_f3_cat2', 'nuniq_keys_f1_cat3', 'nuniq_keys_f2_cat3',
#        'nuniq_keys_f3_cat3', 'nuniq_keys_f1_cat4', 'nuniq_keys_f2_cat4',
#        'nuniq_keys_f3_cat4', 'nuniq_keys_f1_cat5', 'nuniq_keys_f2_cat5',
#        'nuniq_keys_f3_cat5', 'nuniq_keys_f1', 'nuniq_keys_f1.1',
#        'nuniq_keys_f1.2', 'sumval_keys_f1_cat0', 'sumval_keys_f2_cat0',
#        'sumval_keys_f3_cat0', 'sumval_keys_f1_cat1', 'sumval_keys_f2_cat1',
#        'sumval_keys_f3_cat1', 'sumval_keys_f1_cat2', 'sumval_keys_f2_cat2',
#        'sumval_keys_f3_cat2', 'sumval_keys_f1_cat3', 'sumval_keys_f2_cat3',
#        'sumval_keys_f3_cat3', 'sumval_keys_f1_cat4', 'sumval_keys_f2_cat4',
#        'sumval_keys_f3_cat4', 'sumval_keys_f1_cat5', 'sumval_keys_f2_cat5',
#        'sumval_keys_f3_cat5', 'sumval_keys_f1', 'sumval_keys_f1.1',
#        'sumval_keys_f1.2', 'most_freq_cat', 'diff_num_cats', 'unique_days',
#        'target', 'max_f1', 'max_f2', 'max_f3'],
#       dtype='object')

# %%
train_cols = ['num_times_cat_eq_0', 'num_times_cat_eq_1', 'num_times_cat_eq_2',
       'num_times_cat_eq_3', 'num_times_cat_eq_4', 'num_times_cat_eq_5',
       'records', 'max_days', 'min_days', 'sum_values_f1_max',
       'num_keys_f1_max', 'sum_values_f2_max', 'num_keys_f2_max',
       'sum_values_f3_max', 'num_keys_f3_max', 'sum_values_f1_mean',
       'num_keys_f1_mean', 'sum_values_f2_mean', 'num_keys_f2_mean',
       'sum_values_f3_mean', 'num_keys_f3_mean', 'max_day_cntr',
       'mean_day_cntr', 'nuniq_keys_f1_cat0', 'nuniq_keys_f2_cat0',
       'nuniq_keys_f3_cat0', 'nuniq_keys_f1_cat1', 'nuniq_keys_f2_cat1',
       'nuniq_keys_f3_cat1', 'nuniq_keys_f1_cat2', 'nuniq_keys_f2_cat2',
       'nuniq_keys_f3_cat2', 'nuniq_keys_f1_cat3', 'nuniq_keys_f2_cat3',
       'nuniq_keys_f3_cat3', 'nuniq_keys_f1_cat4', 'nuniq_keys_f2_cat4',
       'nuniq_keys_f3_cat4', 'nuniq_keys_f1_cat5', 'nuniq_keys_f2_cat5',
       'nuniq_keys_f3_cat5', 'nuniq_keys_f1', 'sumval_keys_f1_cat0', 'sumval_keys_f2_cat0',
       'sumval_keys_f3_cat0', 'sumval_keys_f1_cat1', 'sumval_keys_f2_cat1',
       'sumval_keys_f3_cat1', 'sumval_keys_f1_cat2', 'sumval_keys_f2_cat2',
       'sumval_keys_f3_cat2', 'sumval_keys_f1_cat3', 'sumval_keys_f2_cat3',
       'sumval_keys_f3_cat3', 'sumval_keys_f1_cat4', 'sumval_keys_f2_cat4',
       'sumval_keys_f3_cat4', 'sumval_keys_f1_cat5', 'sumval_keys_f2_cat5',
       'sumval_keys_f3_cat5', 'sumval_keys_f1', 'most_freq_cat', 'diff_num_cats', 'unique_days',
       'max_f1', 'max_f2', 'max_f3']

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(-1,1))
scaler.fit(X[train_cols].fillna(0).values)
X[train_cols] = scaler.transform(X[train_cols].fillna(0).values)
x_te[train_cols] = scaler.transform(x_te[train_cols].fillna(0).values)

# %%
import math
from sklearn.metrics import log_loss
class CyclicLR(Callback):
    """This callback implements a cyclical learning rate policy (CLR).
    The method cycles the learning rate between two boundaries with
    some constant frequency, as detailed in this paper (https://arxiv.org/abs/1506.01186).
    The amplitude of the cycle can be scaled on a per-iteration or 
    per-cycle basis.
    This class has three built-in policies, as put forth in the paper.
    "triangular":
        A basic triangular cycle w/ no amplitude scaling.
    "triangular2":
        A basic triangular cycle that scales initial amplitude by half each cycle.
    "exp_range":
        A cycle that scales initial amplitude by gamma**(cycle iterations) at each 
        cycle iteration.
    For more detail, please see paper.
    
    # Example
        ```python
            clr = CyclicLR(base_lr=0.001, max_lr=0.006,
                                step_size=2000., mode='triangular')
            model.fit(X_train, Y_train, callbacks=[clr])
        ```
    
    Class also supports custom scaling functions:
        ```python
            clr_fn = lambda x: 0.5*(1+np.sin(x*np.pi/2.))
            clr = CyclicLR(base_lr=0.001, max_lr=0.006,
                                step_size=2000., scale_fn=clr_fn,
                                scale_mode='cycle')
            model.fit(X_train, Y_train, callbacks=[clr])
        ```    
    # Arguments
        base_lr: initial learning rate which is the
            lower boundary in the cycle.
        max_lr: upper boundary in the cycle. Functionally,
            it defines the cycle amplitude (max_lr - base_lr).
            The lr at any cycle is the sum of base_lr
            and some scaling of the amplitude; therefore 
            max_lr may not actually be reached depending on
            scaling function.
        step_size: number of training iterations per
            half cycle. Authors suggest setting step_size
            2-8 x training iterations in epoch.
        mode: one of {triangular, triangular2, exp_range}.
            Default 'triangular'.
            Values correspond to policies detailed above.
            If scale_fn is not None, this argument is ignored.
        gamma: constant in 'exp_range' scaling function:
            gamma**(cycle iterations)
        scale_fn: Custom scaling policy defined by a single
            argument lambda function, where 
            0 <= scale_fn(x) <= 1 for all x >= 0.
            mode paramater is ignored 
        scale_mode: {'cycle', 'iterations'}.
            Defines whether scale_fn is evaluated on 
            cycle number or cycle iterations (training
            iterations since start of cycle). Default is 'cycle'.
    """

    def __init__(self, base_lr=0.001, max_lr=0.006, step_size=2000., mode='triangular',
                 gamma=1., scale_fn=None, scale_mode='cycle'):
        super(CyclicLR, self).__init__()

        self.base_lr = base_lr
        self.max_lr = max_lr
        self.step_size = step_size
        self.mode = mode
        self.gamma = gamma
        if scale_fn == None:
            if self.mode == 'triangular':
                self.scale_fn = lambda x: 1.
                self.scale_mode = 'cycle'
            elif self.mode == 'triangular2':
                self.scale_fn = lambda x: 1/(2.**(x-1))
                self.scale_mode = 'cycle'
            elif self.mode == 'exp_range':
                self.scale_fn = lambda x: gamma**(x)
                self.scale_mode = 'iterations'
        else:
            self.scale_fn = scale_fn
            self.scale_mode = scale_mode
        self.clr_iterations = 0.
        self.trn_iterations = 0.
        self.history = {}

        self._reset()

    def _reset(self, new_base_lr=None, new_max_lr=None,
               new_step_size=None):
        """Resets cycle iterations.
        Optional boundary/step size adjustment.
        """
        if new_base_lr != None:
            self.base_lr = new_base_lr
        if new_max_lr != None:
            self.max_lr = new_max_lr
        if new_step_size != None:
            self.step_size = new_step_size
        self.clr_iterations = 0.
        
    def clr(self):
        cycle = np.floor(1+self.clr_iterations/(2*self.step_size))
        x = np.abs(self.clr_iterations/self.step_size - 2*cycle + 1)
        if self.scale_mode == 'cycle':
            return self.base_lr + (self.max_lr-self.base_lr)*np.maximum(0, (1-x))*self.scale_fn(cycle)
        else:
            return self.base_lr + (self.max_lr-self.base_lr)*np.maximum(0, (1-x))*self.scale_fn(self.clr_iterations)
        
    def on_train_begin(self, logs={}):
        logs = logs or {}

        if self.clr_iterations == 0:
            K.set_value(self.model.optimizer.lr, self.base_lr)
        else:
            K.set_value(self.model.optimizer.lr, self.clr())        
            
    def on_batch_end(self, epoch, logs=None):
        
        logs = logs or {}
        self.trn_iterations += 1
        self.clr_iterations += 1
        K.set_value(self.model.optimizer.lr, self.clr())

        self.history.setdefault('lr', []).append(K.get_value(self.model.optimizer.lr))
        self.history.setdefault('iterations', []).append(self.trn_iterations)

        for k, v in logs.items():
            self.history.setdefault(k, []).append(v)

            
class RocAucEvaluation(Callback):
    def __init__(self, X_seq, y, name, interval=1):
        super(Callback, self).__init__()
        self.X_seq, self.y = X_seq, y
        self.name = name
        self.interval = interval

    def on_epoch_end(self, epoch, logs={}):
        if epoch % self.interval == 0:
            y_pred = self.model.predict_generator(self.X_seq, steps=len(self.X_seq), 
                                                          use_multiprocessing=False, workers=1, 
                                                          max_queue_size=4*cpu_cores).ravel()
            auc = roc_auc_score(self.y, y_pred)
            logloss = log_loss(self.y, y_pred)
            logs[self.name+"_auc"] = auc
            logs[self.name+"_logloss"] = logloss
            print((self.name+"_auc: {:.8f}; "+"_logloss: {:.8f}; ").format(auc,logloss))
            
class FeatureSequence(Sequence):
    
    def __init__(self, X, y, inx, batch_size, shuffle=False):
        
        self.X, self.y = X, y
        self.batch_size = batch_size
        
        self.inx = inx
        self.shuffle = shuffle
        if self.shuffle:
            np.random.shuffle(self.inx)

    def __len__(self):
        return math.ceil(self.inx.shape[0] / self.batch_size)

    def __getitem__(self, i):
        batch_inx = self.inx[i*self.batch_size:(i+1)*self.batch_size]
        
        batch = [x[batch_inx] for x in self.X[:3]] +  [x[batch_inx].todense() for x in self.X[-3:]]
        #batch = [x[batch_inx].todense() for x in self.X]
        return batch, self.y[batch_inx]
    
    def on_epoch_end(self):
        if self.shuffle:
            np.random.shuffle(self.inx)

# %%
train_mat1.shape
# Out:
# (427994, 11181)

# %%
model_name = "all_in_focal_loss2"

def split_inputs(X):
    return np.split(X, X.shape[-1], axis=-1)

def buildBaseModel():   
    num_inp = Input((len(train_cols),), name='num_inp')
    num_x = BatchNormalization()(num_inp)
    num_x = Dense(64, activation="relu")(num_x)
    num_x = BatchNormalization()(num_x)
    num_x = Dropout(0.3)(num_x)
    
    dense_inp1 = Input((train_mat1_pca.shape[1],), name='dense_inp1')
    dense1_x = BatchNormalization()(dense_inp1)
    dense1_x = Dropout(0.3)(dense1_x)
    
    dense_inp3 = Input((train_mat3_pca.shape[1],), name='dense_inp3')
    dense3_x = BatchNormalization()(dense_inp3)
    dense3_x = Dropout(0.3)(dense3_x)
    
    sparse_inp1 = Input((train_mat1.shape[1],), name='sparse_inp1')
    sparse1_x = BatchNormalization()(sparse_inp1)
    sparse1_x = Dense(128, activation="relu")(sparse1_x)
    sparse1_x = BatchNormalization()(sparse1_x)
    sparse1_x = Dropout(0.3)(sparse1_x)
    
    sparse_inp2 = Input((train_mat2.shape[1],), name='sparse_inp2')
    sparse2_x = BatchNormalization()(sparse_inp2)
    sparse2_x = Dense(256, activation="relu")(sparse2_x)
    sparse2_x = BatchNormalization()(sparse2_x)
    sparse2_x = Dropout(0.3)(sparse2_x)
    
    sparse_inp3 = Input((train_mat3.shape[1],), name='sparse_inp3')
    sparse3_x = BatchNormalization()(sparse_inp3)
    #sparse3_x = Dense(128, activation="relu")(sparse3_x)
    #sparse3_x = BatchNormalization()(sparse3_x)
    #sparse3_x = Dropout(0.1)(sparse3_x)    
    
    x = concatenate([num_x, dense1_x, dense3_x, sparse1_x, sparse3_x, sparse2_x]) #, sparse1_x, sparse3_x
    #x = num_x
    
    x1 = Dense(256, activation="relu")(x)
    x1 = BatchNormalization()(x1)
    x1 = Dropout(0.3)(x1)
    
    x4 = Dense(128, activation="relu")(x1)
    x4 = BatchNormalization()(x4)
    x4 = Dropout(0.3)(x4)

    x4 = Dense(64, activation="relu")(x4)
    x4 = BatchNormalization()(x4)
    x4 = Dropout(0.1)(x4)
    
    x_output = Dense(1, activation="sigmoid", name="output")(x4)
    return Model(inputs = [num_inp, dense_inp1, dense_inp3, sparse_inp1, sparse_inp3, sparse_inp2], outputs=x_output) #num_inp, ,  sparse_inp3

model = buildBaseModel()
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# num_inp (InputLayer)            (None, 67)           0
# __________________________________________________________________________________________________
# sparse_inp1 (InputLayer)        (None, 11970)        0
# __________________________________________________________________________________________________
# sparse_inp2 (InputLayer)        (None, 20275)        0
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 67)           268         num_inp[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 11970)        47880       sparse_inp1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 20275)        81100       sparse_inp2[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 64)           4352        batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# dense_inp1 (InputLayer)         (None, 200)          0
# __________________________________________________________________________________________________
# dense_inp3 (InputLayer)         (None, 200)          0
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 128)          1532288     batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 256)          5190656     batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 64)           256         dense_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 200)          800         dense_inp1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 200)          800         dense_inp3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 128)          512         dense_8[0][0]
# __________________________________________________________________________________________________
# sparse_inp3 (InputLayer)        (None, 1855)         0
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 256)          1024        dense_9[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 64)           0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 200)          0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 200)          0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 128)          0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 1855)         7420        sparse_inp3[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 256)          0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 2703)         0           dropout_9[0][0]
#                                                                  dropout_10[0][0]
#                                                                  dropout_11[0][0]
#                                                                  dropout_12[0][0]
#                                                                  batch_normalization_21[0][0]
#                                                                  dropout_13[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 256)          692224      concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 256)          1024        dense_10[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 256)          0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 128)          32896       dropout_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 128)          512         dense_11[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 128)          0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 64)           8256        dropout_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 64)           256         dense_12[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 64)           0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            65          dropout_16[0][0]
# ==================================================================================================
# Total params: 7,602,589
# Trainable params: 7,531,663
# Non-trainable params: 70,926
# __________________________________________________________________________________________________

# %%
y = X.target.values

# %%
from sklearn.model_selection import KFold
TRN_BATCH_SIZE = 512
INF_BATCH_SIZE = 512

n_folds = 10
kf = KFold(n_splits=n_folds, shuffle=True, random_state=239)
epochs = 32
pred = np.zeros(y.shape)
test_pred = 0
ifold = 0

fold_auc = []

# %%
cpu_cores = 4

def focal_loss(y_true, y_pred, alpha, gamma=0.5):
    alpha = K.variable(alpha)
    pt = K.abs(1. - y_true - y_pred)
    pt = K.clip(pt, K.epsilon(), 1. - K.epsilon())
    return K.mean(-alpha * K.pow(1. - pt, gamma) * K.log(pt), axis=-1)

te_seq = FeatureSequence([x_te[train_cols].values, 
                               test_mat1_pca,
                               test_mat3_pca,
                               test_mat1,
                               test_mat3,
                               test_mat2,
                              
                         ], 
                              y, np.array(list(range(len(x_te)))), INF_BATCH_SIZE, shuffle=False)

for trn_inx, val_inx in kf.split(y):
    print("Training fold {}".format(ifold))
    K.clear_session()
    model = buildBaseModel()
    
    model_file_name = model_name+"__f"+str(ifold)
    model_file = results_dir+model_file_name+'.h5'   
    
    trn_seq = FeatureSequence([X.loc[:,train_cols].values, 
                               train_mat1_pca,
                               train_mat3_pca,
                               train_mat1,
                               train_mat3,
                               train_mat2
                               
                              ], 
                              y, trn_inx, TRN_BATCH_SIZE, shuffle=True)
    val_seq = FeatureSequence([X.loc[:,train_cols].values, 
                               train_mat1_pca,
                               train_mat3_pca,
                               train_mat1,
                               train_mat3,
                               train_mat2
                              ], 
                              y, val_inx, INF_BATCH_SIZE, shuffle=False)
    
    # Callbacks
    model_checkpoint = ModelCheckpoint(model_file, monitor='val_auc', verbose=1, mode='max',
                                       save_best_only=True, save_weights_only=False, period=1)
    clr = CyclicLR(base_lr=0.0001, max_lr=0.0005, step_size=2*math.ceil(len(trn_seq)), mode='triangular2')
    early_stop = EarlyStopping(monitor='val_auc', min_delta=0, patience=3, verbose=1, mode='max')
    mse_eval = RocAucEvaluation(val_seq, y[val_inx], 'val')
    
    alpha = 10
    gamma = 0.25
    #alpha = 0.25
    #gamma = 2
    # Training
    opt=optimizers.Nadam()
    model.compile(optimizer=opt, loss=lambda y_true, y_pred: focal_loss(y_true, y_pred, alpha=alpha, gamma=gamma))

    model.fit_generator(
        generator=trn_seq, steps_per_epoch=len(trn_seq),
        initial_epoch=0, epochs=epochs, shuffle=False, verbose=1,
        callbacks=[mse_eval, model_checkpoint, early_stop, clr], #
        use_multiprocessing=False, workers=1, max_queue_size=4*cpu_cores)
    
     
    # Predicting
    print("\nPredicting fold {}".format(ifold))
    del model  
    model = load_model(model_file, compile=True, custom_objects={'<lambda>':lambda y_true, y_pred: focal_loss(y_true, y_pred, alpha, gamma)})
    pred[val_inx] = model.predict_generator(val_seq, steps=len(val_seq), 
                                                    use_multiprocessing=False, workers=1, 
                                                    max_queue_size=4*cpu_cores).ravel()
    
    auc = roc_auc_score(y[val_inx], pred[val_inx])
    logloss = log_loss(y[val_inx], pred[val_inx])
    fold_auc.append(auc)
    print("fold: {}, auc: {}".format(ifold, auc))
    print("fold: {}, logloss: {}".format(ifold, logloss))
    print()
    
    test_pred += model.predict_generator(te_seq, steps=len(te_seq), 
                                                    use_multiprocessing=False, workers=1, 
                                                    max_queue_size=4*cpu_cores).ravel()/n_folds
    ifold += 1
    gc.collect()
# Out:
# Training fold 1
# Epoch 1/32
# 753/753 [==============================] - 44s 58ms/step - loss: 4.4942
# val_auc: 0.57041139; _logloss: 0.27532997;
#
# Epoch 00001: val_auc improved from -inf to 0.57041, saving model to ./results/all_in_focal_loss2__f1.h5
# Epoch 2/32
# 753/753 [==============================] - 45s 59ms/step - loss: 1.8033
# val_auc: 0.66662589; _logloss: 0.20903088;
#
# Epoch 00002: val_auc improved from 0.57041 to 0.66663, saving model to ./results/all_in_focal_loss2__f1.h5
# Epoch 3/32
# 753/753 [==============================] - 44s 59ms/step - loss: 1.6278
# val_auc: 0.67762048; _logloss: 0.22202441;
#
# Epoch 00003: val_auc improved from 0.66663 to 0.67762, saving model to ./results/all_in_focal_loss2__f1.h5
# Epoch 4/32
# 753/753 [==============================] - 45s 59ms/step - loss: 1.5108
# val_auc: 0.63802618; _logloss: 0.26474046;
#
# Epoch 00004: val_auc did not improve
# Epoch 5/32
# 753/753 [==============================] - 47s 62ms/step - loss: 1.3885
# val_auc: 0.65442810; _logloss: 0.19782370;
#
# Epoch 00005: val_auc did not improve
# Epoch 6/32
# 753/753 [==============================] - 42s 56ms/step - loss: 1.3296
# val_auc: 0.64406384; _logloss: 0.19688048;
#
# Epoch 00006: val_auc did not improve
# Epoch 00006: early stopping
#
# Predicting fold 1
# fold: 1, auc: 0.6776204840472132
# fold: 1, logloss: 0.22202440931178014
#
# Training fold 2
# Epoch 1/32
# 753/753 [==============================] - 46s 61ms/step - loss: 4.4353
# val_auc: 0.57652380; _logloss: 0.28982280;
#
# Epoch 00001: val_auc improved from -inf to 0.57652, saving model to ./results/all_in_focal_loss2__f2.h5
# Epoch 2/32
# 753/753 [==============================] - 42s 56ms/step - loss: 1.7883
# val_auc: 0.64978472; _logloss: 0.22659093;
#
# Epoch 00002: val_auc improved from 0.57652 to 0.64978, saving model to ./results/all_in_focal_loss2__f2.h5
# Epoch 3/32
# 753/753 [==============================] - 42s 56ms/step - loss: 1.6220
# val_auc: 0.66228298; _logloss: 0.19012149;
#
# Epoch 00003: val_auc improved from 0.64978 to 0.66228, saving model to ./results/all_in_focal_loss2__f2.h5
# Epoch 4/32
# 753/753 [==============================] - 44s 59ms/step - loss: 1.5026
# val_auc: 0.65124922; _logloss: 0.19098215;
#
# Epoch 00004: val_auc did not improve
# Epoch 5/32
# 753/753 [==============================] - 45s 59ms/step - loss: 1.3848
# val_auc: 0.63239438; _logloss: 0.20194559;
#
# Epoch 00005: val_auc did not improve
# Epoch 6/32
# 753/753 [==============================] - 45s 59ms/step - loss: 1.3153
# /root/miniconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1694: RuntimeWarning: invalid value encountered in multiply
#   loss = -(transformed_labels * np.log(y_pred)).sum(axis=1)
# val_auc: 0.57125760; _logloss: nan;
#
# Epoch 00006: val_auc did not improve
# Epoch 00006: early stopping
#
# Predicting fold 2
# fold: 2, auc: 0.6622829793738478
# fold: 2, logloss: 0.19012148971545764
#
# Training fold 3
# Epoch 1/32
# 753/753 [==============================] - 47s 62ms/step - loss: 4.4856
# val_auc: 0.57266794; _logloss: 0.27536474;
#
# Epoch 00001: val_auc improved from -inf to 0.57267, saving model to ./results/all_in_focal_loss2__f3.h5
# Epoch 2/32
# 753/753 [==============================] - 44s 59ms/step - loss: 1.8044
# val_auc: 0.64210556; _logloss: 0.19508327;
#
# Epoch 00002: val_auc improved from 0.57267 to 0.64211, saving model to ./results/all_in_focal_loss2__f3.h5
# Epoch 3/32
# 753/753 [==============================] - 46s 62ms/step - loss: 1.6233
# val_auc: 0.65440382; _logloss: 0.19736655;
#
# Epoch 00003: val_auc improved from 0.64211 to 0.65440, saving model to ./results/all_in_focal_loss2__f3.h5
# Epoch 4/32
# 753/753 [==============================] - 45s 59ms/step - loss: 1.4938
# val_auc: 0.65141524; _logloss: 0.19452737;
#
# Epoch 00004: val_auc did not improve
# Epoch 5/32
# 753/753 [==============================] - 44s 59ms/step - loss: 1.3727
# val_auc: 0.63329534; _logloss: 0.19901736;
#
# Epoch 00005: val_auc did not improve
# Epoch 6/32
# 753/753 [==============================] - 42s 56ms/step - loss: 1.2955
# val_auc: 0.61747188; _logloss: 0.21043135;
#
# Epoch 00006: val_auc did not improve
# Epoch 00006: early stopping
#
# Predicting fold 3
# fold: 3, auc: 0.6544038220046599
# fold: 3, logloss: 0.1973665515298887
#
# Training fold 4
# Epoch 1/32
# 753/753 [==============================] - 46s 61ms/step - loss: 4.4116
# val_auc: 0.57831497; _logloss: 0.25716598;
#
# Epoch 00001: val_auc improved from -inf to 0.57831, saving model to ./results/all_in_focal_loss2__f4.h5
# Epoch 2/32
# 753/753 [==============================] - 46s 61ms/step - loss: 1.8306
# val_auc: 0.66349750; _logloss: 0.20010888;
#
# Epoch 00002: val_auc improved from 0.57831 to 0.66350, saving model to ./results/all_in_focal_loss2__f4.h5
# Epoch 3/32
# 753/753 [==============================] - 45s 59ms/step - loss: 1.6477
# val_auc: 0.68059564; _logloss: 0.19026294;
#
# Epoch 00003: val_auc improved from 0.66350 to 0.68060, saving model to ./results/all_in_focal_loss2__f4.h5
# Epoch 4/32
# 753/753 [==============================] - 47s 62ms/step - loss: 1.5305
# val_auc: 0.67618677; _logloss: 0.19194565;
#
# Epoch 00004: val_auc did not improve
# Epoch 5/32
# 753/753 [==============================] - 45s 59ms/step - loss: 1.4125
# val_auc: 0.66315313; _logloss: 0.19675270;
#
# Epoch 00005: val_auc did not improve
# Epoch 6/32
# 753/753 [==============================] - 44s 59ms/step - loss: 1.3514
# /root/miniconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1694: RuntimeWarning: divide by zero encountered in log
#   loss = -(transformed_labels * np.log(y_pred)).sum(axis=1)
# val_auc: 0.65153984; _logloss: nan;
#
# Epoch 00006: val_auc did not improve
# Epoch 00006: early stopping
#
# Predicting fold 4
# fold: 4, auc: 0.6805956408110981
# fold: 4, logloss: 0.1902629395741827
#
# Training fold 5
# Epoch 1/32
# 753/753 [==============================] - 46s 62ms/step - loss: 4.3947
# val_auc: 0.58740798; _logloss: 0.28766914;
#
# Epoch 00001: val_auc improved from -inf to 0.58741, saving model to ./results/all_in_focal_loss2__f5.h5
# Epoch 2/32
# 753/753 [==============================] - 45s 59ms/step - loss: 1.7876
# val_auc: 0.66133410; _logloss: 0.19873818;
#
# Epoch 00002: val_auc improved from 0.58741 to 0.66133, saving model to ./results/all_in_focal_loss2__f5.h5
# Epoch 3/32
# 753/753 [==============================] - 43s 57ms/step - loss: 1.6167
# val_auc: 0.66510616; _logloss: 0.19594283;
#
# Epoch 00003: val_auc improved from 0.66133 to 0.66511, saving model to ./results/all_in_focal_loss2__f5.h5
# Epoch 4/32
# 753/753 [==============================] - 47s 62ms/step - loss: 1.5002
# val_auc: 0.65032067; _logloss: 0.19976397;
#
# Epoch 00004: val_auc did not improve
# Epoch 5/32
# 753/753 [==============================] - 44s 59ms/step - loss: 1.3850
# val_auc: 0.63769262; _logloss: 0.20695490;
#
# Epoch 00005: val_auc did not improve
# Epoch 6/32
# 753/753 [==============================] - 45s 59ms/step - loss: 1.3239
# val_auc: 0.59646035; _logloss: 0.32967304;
#
# Epoch 00006: val_auc did not improve
# Epoch 00006: early stopping
#
# Predicting fold 5
# fold: 5, auc: 0.6651061611077137
# fold: 5, logloss: 0.19594283194744527
#
# Training fold 6
# Epoch 1/32
# 753/753 [==============================] - 46s 62ms/step - loss: 4.4716
# val_auc: 0.56982994; _logloss: 0.27045835;
#
# Epoch 00001: val_auc improved from -inf to 0.56983, saving model to ./results/all_in_focal_loss2__f6.h5
# Epoch 2/32
# 753/753 [==============================] - 42s 56ms/step - loss: 1.8059
# val_auc: 0.65615043; _logloss: 0.19845400;
#
# Epoch 00002: val_auc improved from 0.56983 to 0.65615, saving model to ./results/all_in_focal_loss2__f6.h5
# Epoch 3/32
# 753/753 [==============================] - 42s 56ms/step - loss: 1.6314
# val_auc: 0.66869624; _logloss: 0.19590848;
#
# Epoch 00003: val_auc improved from 0.65615 to 0.66870, saving model to ./results/all_in_focal_loss2__f6.h5
# Epoch 4/32
# 753/753 [==============================] - 45s 59ms/step - loss: 1.5211
# val_auc: 0.65283171; _logloss: 0.19186468;
#
# Epoch 00004: val_auc did not improve
# Epoch 5/32
# 753/753 [==============================] - 45s 59ms/step - loss: 1.4164
# val_auc: 0.63847794; _logloss: 0.19402342;
#
# Epoch 00005: val_auc did not improve
# Epoch 6/32
# 753/753 [==============================] - 45s 60ms/step - loss: 1.3583
# val_auc: 0.62666173; _logloss: 0.24775055;
#
# Epoch 00006: val_auc did not improve
# Epoch 00006: early stopping
#
# Predicting fold 6
# fold: 6, auc: 0.6686962398787055
# fold: 6, logloss: 0.19590848145456985
#
# Training fold 7
# Epoch 1/32
# 753/753 [==============================] - 47s 62ms/step - loss: 4.4605
# val_auc: 0.56284039; _logloss: 0.27422026;
#
# Epoch 00001: val_auc improved from -inf to 0.56284, saving model to ./results/all_in_focal_loss2__f7.h5
# Epoch 2/32
# 753/753 [==============================] - 47s 62ms/step - loss: 1.8180
# val_auc: 0.64782981; _logloss: 0.20086371;
#
# Epoch 00002: val_auc improved from 0.56284 to 0.64783, saving model to ./results/all_in_focal_loss2__f7.h5
# Epoch 3/32
# 753/753 [==============================] - 44s 59ms/step - loss: 1.6418
# val_auc: 0.65282550; _logloss: 0.22221602;
#
# Epoch 00003: val_auc improved from 0.64783 to 0.65283, saving model to ./results/all_in_focal_loss2__f7.h5
# Epoch 4/32
# 753/753 [==============================] - 46s 61ms/step - loss: 1.5321
# val_auc: 0.66059283; _logloss: 0.19898226;
#
# Epoch 00004: val_auc improved from 0.65283 to 0.66059, saving model to ./results/all_in_focal_loss2__f7.h5
# Epoch 5/32
# 753/753 [==============================] - 45s 59ms/step - loss: 1.4327
# val_auc: 0.62456659; _logloss: 0.24881259;
#
# Epoch 00005: val_auc did not improve
# Epoch 6/32
# 753/753 [==============================] - 45s 59ms/step - loss: 1.3804
# val_auc: 0.59745419; _logloss: 0.34886406;
#
# Epoch 00006: val_auc did not improve
# Epoch 7/32
# 753/753 [==============================] - 45s 59ms/step - loss: 1.2639
# val_auc: 0.63915702; _logloss: 0.20277156;
#
# Epoch 00007: val_auc did not improve
# Epoch 00007: early stopping
#
# Predicting fold 7
# fold: 7, auc: 0.6605928286996325
# fold: 7, logloss: 0.19898226495140423
#
# Training fold 8
# Epoch 1/32
# 753/753 [==============================] - 47s 62ms/step - loss: 4.4697
# val_auc: 0.56859969; _logloss: 0.27289516;
#
# Epoch 00001: val_auc improved from -inf to 0.56860, saving model to ./results/all_in_focal_loss2__f8.h5
# Epoch 2/32
# 753/753 [==============================] - 45s 60ms/step - loss: 1.8133
# val_auc: 0.65617857; _logloss: 0.20054476;
#
# Epoch 00002: val_auc improved from 0.56860 to 0.65618, saving model to ./results/all_in_focal_loss2__f8.h5
# Epoch 3/32
# 753/753 [==============================] - 47s 63ms/step - loss: 1.6325
# val_auc: 0.67129748; _logloss: 0.18811736;
#
# Epoch 00003: val_auc improved from 0.65618 to 0.67130, saving model to ./results/all_in_focal_loss2__f8.h5
# Epoch 4/32
# 753/753 [==============================] - 47s 63ms/step - loss: 1.5190
# val_auc: 0.66402583; _logloss: 0.19120511;
#
# Epoch 00004: val_auc did not improve
# Epoch 5/32
# 753/753 [==============================] - 44s 59ms/step - loss: 1.4067
# val_auc: 0.64311429; _logloss: 0.19474837;
#
# Epoch 00005: val_auc did not improve
# Epoch 6/32
# 753/753 [==============================] - 44s 59ms/step - loss: 1.3427
# val_auc: 0.63921628; _logloss: 0.19505282;
#
# Epoch 00006: val_auc did not improve
# Epoch 00006: early stopping
#
# Predicting fold 8
# fold: 8, auc: 0.6712974797627239
# fold: 8, logloss: 0.18811735583930178
#
# Training fold 9
# Epoch 1/32
# 753/753 [==============================] - 49s 65ms/step - loss: 4.4074
# val_auc: 0.56130470; _logloss: 0.27024564;
#
# Epoch 00001: val_auc improved from -inf to 0.56130, saving model to ./results/all_in_focal_loss2__f9.h5
# Epoch 2/32
# 753/753 [==============================] - 42s 56ms/step - loss: 1.8018
# val_auc: 0.64724898; _logloss: 0.19789390;
#
# Epoch 00002: val_auc improved from 0.56130 to 0.64725, saving model to ./results/all_in_focal_loss2__f9.h5
# Epoch 3/32
# 753/753 [==============================] - 45s 59ms/step - loss: 1.6252
# val_auc: 0.65581634; _logloss: 0.21425215;
#
# Epoch 00003: val_auc improved from 0.64725 to 0.65582, saving model to ./results/all_in_focal_loss2__f9.h5
# Epoch 4/32
# 753/753 [==============================] - 45s 60ms/step - loss: 1.5075
# val_auc: 0.66042014; _logloss: 0.19240299;
#
# Epoch 00004: val_auc improved from 0.65582 to 0.66042, saving model to ./results/all_in_focal_loss2__f9.h5
# Epoch 5/32
# 753/753 [==============================] - 44s 59ms/step - loss: 1.3895
# val_auc: 0.63351596; _logloss: 0.22384957;
#
# Epoch 00005: val_auc did not improve
# Epoch 6/32
# 753/753 [==============================] - 43s 57ms/step - loss: 1.3252
# val_auc: 0.62938337; _logloss: 0.22635851;
#
# Epoch 00006: val_auc did not improve
# Epoch 7/32
# 753/753 [==============================] - 45s 59ms/step - loss: 1.2035
# val_auc: 0.61177697; _logloss: 0.22675655;
#
# Epoch 00007: val_auc did not improve
# Epoch 00007: early stopping
#
# Predicting fold 9
# fold: 9, auc: 0.6604201441013048
# fold: 9, logloss: 0.1924029863941795
#
# Training fold 10
# Epoch 1/32
# 753/753 [==============================] - 49s 65ms/step - loss: 4.4452
# val_auc: 0.58372945; _logloss: 0.27368309;
#
# Epoch 00001: val_auc improved from -inf to 0.58373, saving model to ./results/all_in_focal_loss2__f10.h5
# Epoch 2/32
# 753/753 [==============================] - 45s 59ms/step - loss: 1.7905
# val_auc: 0.65354840; _logloss: 0.20395145;
#
# Epoch 00002: val_auc improved from 0.58373 to 0.65355, saving model to ./results/all_in_focal_loss2__f10.h5
# Epoch 3/32
# 753/753 [==============================] - 42s 56ms/step - loss: 1.6189
# val_auc: 0.66056695; _logloss: 0.20983651;
#
# Epoch 00003: val_auc improved from 0.65355 to 0.66057, saving model to ./results/all_in_focal_loss2__f10.h5
# Epoch 4/32
# 753/753 [==============================] - 46s 61ms/step - loss: 1.5022
# val_auc: 0.65528405; _logloss: 0.19421258;
#
# Epoch 00004: val_auc did not improve
# Epoch 5/32
# 753/753 [==============================] - 45s 59ms/step - loss: 1.3749
# val_auc: 0.57613989; _logloss: 0.90958222;
#
# Epoch 00005: val_auc did not improve
# Epoch 6/32
# 753/753 [==============================] - 44s 59ms/step - loss: 1.3103
# val_auc: 0.57313203; _logloss: 0.62148506;
#
# Epoch 00006: val_auc did not improve
# Epoch 00006: early stopping
#
# Predicting fold 10
# fold: 10, auc: 0.6605669477916805
# fold: 10, logloss: 0.20983650567567158

# %%
print(fold_auc)
print(np.mean(fold_auc), np.std(fold_auc))
# Out:
# [0.67471445792908868, 0.6776204840472132, 0.66228297937384784, 0.65440382200465985, 0.68059564081109813, 0.6651061611077137, 0.66869623987870552, 0.66059282869963254, 0.67129747976272391, 0.66042014410130478, 0.66056694779168046]
# 0.666936107773 0.00791248017156

# %%
roc_auc_score(X.target.values, pred)
# Out:
# 0.63786306125906367

# %%
model_name = 'all_in_focal_loss3'
np.save(results_dir + 'train_' + model_name +'.npy', pred)
sample_sub = pd.read_table(data_dir+'mlboot_test.tsv')

# %%
sub = x_te[['uid','target']].copy()
sub['target'] = test_pred
sub.columns = ['cuid','target']
sample_sub = sample_sub.merge(sub, on='cuid', how='left')
np.save(results_dir + 'test_' + model_name +'.npy', sample_sub.target.values)
print('isnull?',sample_sub.target.isnull().any())
sample_sub.head()
# Out:
# isnull? False
#                                cuid    target
# 0  888b238b4d14c03173baa375a739f6bc  0.136816
# 1  ac4b8244f3ae82df511b002257473c11  0.073512
# 2  483d8b91e49522c8a5bbe37f3872c749  0.196816
# 3  4c7ec46a0e88a7e1e1cedd2d526d5d61  0.057116
# 4  fdbfba9842ff0bf86d600eb334c7c42b  0.102871

# %%
sample_sub[['target']].to_csv(results_dir + model_name + '.csv', header=False, index=False)

# %%
print(fold_auc)
print(np.mean(fold_auc), np.std(fold_auc))
# Out:
# [0.6644702445490992, 0.64294169489778663, 0.63130878709266391, 0.65312112328188054, 0.65141053255286208, 0.65287791990095678, 0.65218096819032323, 0.65849314197669018, 0.64645771109742023, 0.64635569082469579]
# 0.649961781436 0.0085515308576

# %%
from sklearn.preprocessing import minmax_scale
a = pd.DataFrame()
a['sol0'] = minmax_scale(pd.read_csv(results_dir + 'nn_base_model.csv', header=None)[0].values)
a['sol2'] = minmax_scale(pd.read_csv(results_dir + 'baseline_sparse_10folds.csv', header=None)[0].values)
a.corr()

# %%
a['target'] = a.sol0*0.05 + a.sol2*0.95

a.head()
# Out:
#        sol0      sol2    target
# 0  0.325992  0.184876  0.191932
# 1  0.231779  0.096343  0.103115
# 2  0.242137  0.151491  0.156023
# 3  0.214527  0.055863  0.063797
# 4  0.132649  0.051491  0.055549

# %%
a.corr()
# Out:
#             sol0      sol2    target
# sol0    1.000000  0.323359  0.441124
# sol2    0.323359  1.000000  0.991874
# target  0.441124  0.991874  1.000000

# %%
a[['target']].to_csv(results_dir + 'blend' + '.csv', header=False, index=False)
